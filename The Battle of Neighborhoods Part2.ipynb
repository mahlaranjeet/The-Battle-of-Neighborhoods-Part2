# %% [markdown]
# # The Battle of the Neighbourhoods: PART2

# %% [markdown]
# DATA PREPERATION

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]

# %%
# Change 'Postcode' column title to 'PostalCode'
df.rename(columns={"Postcode": "PostalCode"})

# Drop all rows that are not assigned to a borough
indexNames = df[ df['Borough'] == 'Not assigned' ].index
df.drop(indexNames , inplace=True)

# Regroup all neighbourhoods that fall under the same borough so that they are comma seperated and in one row
df1 = df.groupby(by=['Postcode','Borough']).agg(lambda x: ', '.join(x))
df1.reset_index(level=['Postcode','Borough'], inplace=True)
df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']
df1
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Rouge, Malvern
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Ionview, Kennedy Park
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Henry Farm, Oriole
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Flemingdon Park, Don Mills South
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                     Northwood Park, York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dovercourt Village, Dufferin
# 77                            Little Portugal, Trinity
# 78        Brockton, Exhibition Place, Parkdale Village
# 79                  Downsview, North Park, Upwood Park
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 81                       The Junction North, Runnymede
# 82                       High Park, The Junction South
# 83                              Parkdale, Roncesvalles
# 84                                  Runnymede, Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89                              Alderwood, Long Branch
# 90       The Kingsway, Montgomery Road, Old Mill North
# 91   Humber Bay, King's Mill Park, Kingsway Park So...
# 92   Kingsway Park South West, Mimico NW, The Queen...
# 93                                    Islington Avenue
# 94   Cloverdale, Islington, Martin Grove, Princess ...
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 96                                       Humber Summit
# 97                                    Emery, Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, Martin Grove Gardens, Richv...
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
geo_data=pd.read_csv("https://cocl.us/Geospatial_data")
geo_data
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# ..          ...        ...        ...
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df1['Latitude']=geo_data['Latitude'].values
df1['Longitude']=geo_data['Longitude'].values
df1
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 7                      Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 8      Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 9                          Birch Cliff, Cliffside West  43.692657 -79.264848
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 11                                   Maryvale, Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            Silver Hills, York Mills  43.757490 -79.374714
# 21                             Newtonbrook, Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                            Little Portugal, Trinity  43.647927 -79.419750
# 78        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 79                  Downsview, North Park, Upwood Park  43.713756 -79.490074
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 81                       The Junction North, Runnymede  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Runnymede, Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89                              Alderwood, Long Branch  43.602414 -79.543484
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 91   Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 92   Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Emery, Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
import json
import requests
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
print('All libraries imported!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          3.2.0-py36_0      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# All libraries imported!

# %%
toronto_data= df1[df1['Borough'].str.contains('Toronto', na = False)].reset_index(drop=True)
toronto_data.head()
# Out:
#   Postcode          Borough                   Neighbourhood   Latitude  \
# 0      M4E     East Toronto                     The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3      M4M     East Toronto                 Studio District  43.659526
# 4      M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %%
latitude = 43.6532
longitude= -79.3832

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'XSIRDRTD24EVIEDXMYUFVPCLAFGSI0DRWDIOYXUHMXOUM5AW' # your Foursquare ID
CLIENT_SECRET = 'OLEIA4CUV2AG1RIUNMKMGAS4PQFIO1GHTUO2VPMBRB40NWF0' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: XSIRDRTD24EVIEDXMYUFVPCLAFGSI0DRWDIOYXUHMXOUM5AW
# CLIENT_SECRET:OLEIA4CUV2AG1RIUNMKMGAS4PQFIO1GHTUO2VPMBRB40NWF0

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighbourhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Business Reply Mail Processing Centre 969 Eastern

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1709, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  The Beaches              43.676357              -79.293031
# 1  The Beaches              43.676357              -79.293031
# 2  The Beaches              43.676357              -79.293031
# 3  The Beaches              43.676357              -79.293031
# 4  The Beaches              43.676357              -79.293031
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0                   Glen Manor Ravine       43.676821       -79.293942
# 1  The Big Carrot Natural Food Market       43.678879       -79.297734
# 2                 Grover Pub and Grub       43.679181       -79.297215
# 3                 Glen Stewart Ravine       43.676300       -79.294784
# 4                       Upper Beaches       43.680563       -79.292869
#
#          Venue Category
# 0                 Trail
# 1     Health Food Store
# 2                   Pub
# 3  Other Great Outdoors
# 4          Neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
cols=list(toronto_onehot.columns.values)
cols.pop(cols.index('Neighborhood'))
toronto_onehot=toronto_onehot[['Neighborhood']+cols]

# rename Neighborhood for Neighbourhood so that future merge works
toronto_onehot.rename(columns = {'Neighborhood': 'Neighbourhood'}, inplace = True)
toronto_onehot.head()
toronto_onehot.shape
# Out:
# (1709, 231)

# %%
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
toronto_grouped.shape
# Out:
# (38, 231)

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#              venue  freq
# 0      Coffee Shop  0.08
# 1             Café  0.05
# 2       Steakhouse  0.04
# 3              Bar  0.04
# 4  Thai Restaurant  0.03
#
#
# ----Berczy Park----
#             venue  freq
# 0     Coffee Shop  0.09
# 1    Cocktail Bar  0.05
# 2  Farmers Market  0.04
# 3      Steakhouse  0.04
# 4        Beer Bar  0.04
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#             venue  freq
# 0            Café  0.09
# 1  Breakfast Spot  0.09
# 2     Coffee Shop  0.09
# 3             Bar  0.05
# 4             Gym  0.05
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#             venue  freq
# 0         Brewery  0.07
# 1      Skate Park  0.07
# 2   Garden Center  0.07
# 3          Garden  0.07
# 4  Farmers Market  0.07
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#                 venue  freq
# 0     Airport Service  0.21
# 1      Airport Lounge  0.14
# 2    Airport Terminal  0.14
# 3            Boutique  0.07
# 4  Airport Food Court  0.07
#
#
# ----Cabbagetown, St. James Town----
#                 venue  freq
# 0          Restaurant  0.06
# 1         Coffee Shop  0.06
# 2                Café  0.04
# 3        Gourmet Shop  0.04
# 4  Italian Restaurant  0.04
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.14
# 1                Café  0.06
# 2  Italian Restaurant  0.05
# 3        Burger Joint  0.04
# 4      Ice Cream Shop  0.04
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                            venue  freq
# 0                           Café  0.07
# 1  Vegetarian / Vegan Restaurant  0.06
# 2             Chinese Restaurant  0.05
# 3                            Bar  0.05
# 4                         Bakery  0.04
#
#
# ----Christie----
#                venue  freq
# 0               Café  0.20
# 1      Grocery Store  0.20
# 2               Park  0.13
# 3  Convenience Store  0.07
# 4              Diner  0.07
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1  Japanese Restaurant  0.06
# 2     Sushi Restaurant  0.05
# 3              Gay Bar  0.05
# 4           Restaurant  0.03
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                Hotel  0.06
# 2                 Café  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0        Dessert Shop  0.08
# 1      Sandwich Place  0.08
# 2         Pizza Place  0.08
# 3  Italian Restaurant  0.05
# 4                Café  0.05
#
#
# ----Davisville North----
#             venue  freq
# 0     Pizza Place  0.11
# 1    Dance Studio  0.11
# 2  Sandwich Place  0.11
# 3  Breakfast Spot  0.11
# 4  Clothing Store  0.11
#
#
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
#               venue  freq
# 0               Pub  0.13
# 1       Coffee Shop  0.13
# 2        Sports Bar  0.07
# 3  Sushi Restaurant  0.07
# 4       Supermarket  0.07
#
#
# ----Design Exchange, Toronto Dominion Centre----
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.08
# 2        Hotel  0.06
# 3   Restaurant  0.05
# 4       Bakery  0.03
#
#
# ----Dovercourt Village, Dufferin----
#                    venue  freq
# 0                 Bakery  0.12
# 1               Pharmacy  0.12
# 2            Supermarket  0.12
# 3  Portuguese Restaurant  0.06
# 4                   Park  0.06
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0  Coffee Shop  0.09
# 1         Café  0.08
# 2        Hotel  0.05
# 3   Steakhouse  0.04
# 4   Restaurant  0.04
#
#
# ----Forest Hill North, Forest Hill West----
#                venue  freq
# 0           Bus Line  0.25
# 1              Trail  0.25
# 2   Sushi Restaurant  0.25
# 3      Jewelry Store  0.25
# 4  Afghan Restaurant  0.00
#
#
# ----Harbord, University of Toronto----
#                  venue  freq
# 0                 Café  0.17
# 1               Bakery  0.06
# 2            Bookstore  0.06
# 3       Sandwich Place  0.06
# 4  Japanese Restaurant  0.06
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#             venue  freq
# 0     Coffee Shop  0.13
# 1        Aquarium  0.05
# 2           Hotel  0.05
# 3            Café  0.04
# 4  Scenic Lookout  0.03
#
#
# ----Harbourfront, Regent Park----
#          venue  freq
# 0  Coffee Shop  0.16
# 1         Café  0.06
# 2         Park  0.06
# 3       Bakery  0.06
# 4          Pub  0.06
#
#
# ----High Park, The Junction South----
#                        venue  freq
# 0                       Café  0.09
# 1         Mexican Restaurant  0.09
# 2              Grocery Store  0.05
# 3  Cajun / Creole Restaurant  0.05
# 4        Fried Chicken Joint  0.05
#
#
# ----Lawrence Park----
#                venue  freq
# 0               Park  0.25
# 1           Bus Line  0.25
# 2               Lake  0.25
# 3        Swim School  0.25
# 4  Afghan Restaurant  0.00
#
#
# ----Little Portugal, Trinity----
#                venue  freq
# 0                Bar  0.13
# 1   Asian Restaurant  0.05
# 2        Coffee Shop  0.05
# 3  French Restaurant  0.03
# 4       Cocktail Bar  0.03
#
#
# ----Moore Park, Summerhill East----
#                      venue  freq
# 0               Playground  0.25
# 1                     Park  0.25
# 2                    Trail  0.25
# 3             Tennis Court  0.25
# 4  New American Restaurant  0.00
#
#
# ----North Toronto West----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1  Sporting Goods Shop  0.10
# 2          Yoga Studio  0.05
# 3           Restaurant  0.05
# 4         Burger Joint  0.05
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0               Breakfast Spot  0.13
# 1                    Gift Shop  0.13
# 2                Movie Theater  0.07
# 3  Eastern European Restaurant  0.07
# 4             Cuban Restaurant  0.07
#
#
# ----Rosedale----
#                      venue  freq
# 0                     Park   0.4
# 1               Playground   0.2
# 2                 Building   0.2
# 3                    Trail   0.2
# 4  New American Restaurant   0.0
#
#
# ----Roselawn----
#             venue  freq
# 0    Home Service  0.25
# 1  Ice Cream Shop  0.25
# 2     Music Venue  0.25
# 3          Garden  0.25
# 4       Nightclub  0.00
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0                Café  0.09
# 1         Coffee Shop  0.09
# 2    Sushi Restaurant  0.06
# 3  Italian Restaurant  0.06
# 4           Gastropub  0.03
#
#
# ----Ryerson, Garden District----
#                        venue  freq
# 0                Coffee Shop  0.09
# 1             Clothing Store  0.08
# 2                       Café  0.03
# 3  Middle Eastern Restaurant  0.03
# 4             Cosmetics Shop  0.03
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1                Café  0.06
# 2          Restaurant  0.05
# 3               Hotel  0.05
# 4  Italian Restaurant  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1  Italian Restaurant  0.05
# 2                Café  0.04
# 3          Restaurant  0.04
# 4        Cocktail Bar  0.03
#
#
# ----Studio District----
#                  venue  freq
# 0                 Café  0.11
# 1          Coffee Shop  0.08
# 2   Italian Restaurant  0.05
# 3  American Restaurant  0.05
# 4               Bakery  0.05
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0     Coffee Shop  0.12
# 1  Sandwich Place  0.12
# 2            Café  0.12
# 3     Pizza Place  0.08
# 4       BBQ Joint  0.04
#
#
# ----The Beaches----
#                   venue  freq
# 0                 Trail   0.2
# 1  Other Great Outdoors   0.2
# 2     Health Food Store   0.2
# 3                   Pub   0.2
# 4                Museum   0.0
#
#
# ----The Beaches West, India Bazaar----
#               venue  freq
# 0              Park  0.13
# 1       Pizza Place  0.09
# 2    Sandwich Place  0.09
# 3  Sushi Restaurant  0.04
# 4         Pet Store  0.04
#
#
# ----The Danforth West, Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.20
# 1             Coffee Shop  0.09
# 2      Italian Restaurant  0.07
# 3          Ice Cream Shop  0.05
# 4  Furniture / Home Store  0.05

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                         Neighbourhood 1st Most Common Venue  \
# 0                            Adelaide, King, Richmond           Coffee Shop
# 1                                         Berczy Park           Coffee Shop
# 2        Brockton, Exhibition Place, Parkdale Village           Coffee Shop
# 3   Business Reply Mail Processing Centre 969 Eastern            Comic Shop
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...       Airport Service
# 5                         Cabbagetown, St. James Town           Coffee Shop
# 6                                  Central Bay Street           Coffee Shop
# 7           Chinatown, Grange Park, Kensington Market                  Café
# 8                                            Christie                  Café
# 9                                Church and Wellesley           Coffee Shop
# 10                     Commerce Court, Victoria Hotel           Coffee Shop
# 11                                         Davisville        Sandwich Place
# 12                                   Davisville North           Pizza Place
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...           Coffee Shop
# 14           Design Exchange, Toronto Dominion Centre           Coffee Shop
# 15                       Dovercourt Village, Dufferin              Pharmacy
# 16             First Canadian Place, Underground city           Coffee Shop
# 17                Forest Hill North, Forest Hill West                 Trail
# 18                     Harbord, University of Toronto                  Café
# 19  Harbourfront East, Toronto Islands, Union Station           Coffee Shop
# 20                          Harbourfront, Regent Park           Coffee Shop
# 21                      High Park, The Junction South                  Café
# 22                                      Lawrence Park                  Park
# 23                           Little Portugal, Trinity                   Bar
# 24                        Moore Park, Summerhill East            Playground
# 25                                 North Toronto West   Sporting Goods Shop
# 26                             Parkdale, Roncesvalles        Breakfast Spot
# 27                                           Rosedale                  Park
# 28                                           Roselawn                Garden
# 29                                 Runnymede, Swansea           Coffee Shop
# 30                           Ryerson, Garden District           Coffee Shop
# 31                                     St. James Town           Coffee Shop
# 32                    Stn A PO Boxes 25 The Esplanade           Coffee Shop
# 33                                    Studio District                  Café
# 34                The Annex, North Midtown, Yorkville           Coffee Shop
# 35                                        The Beaches     Health Food Store
# 36                     The Beaches West, India Bazaar                  Park
# 37                       The Danforth West, Riverdale      Greek Restaurant
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 0                            Café                   Bar
# 1                    Cocktail Bar           Cheese Shop
# 2                            Café        Breakfast Spot
# 3                   Garden Center               Brewery
# 4                  Airport Lounge      Airport Terminal
# 5                      Restaurant           Pizza Place
# 6                            Café    Italian Restaurant
# 7   Vegetarian / Vegan Restaurant    Chinese Restaurant
# 8                   Grocery Store                  Park
# 9             Japanese Restaurant               Gay Bar
# 10                           Café                 Hotel
# 11                    Pizza Place          Dessert Shop
# 12                          Hotel     Food & Drink Shop
# 13                            Pub    Light Rail Station
# 14                           Café                 Hotel
# 15                    Supermarket                Bakery
# 16                           Café                 Hotel
# 17                  Jewelry Store      Sushi Restaurant
# 18                            Bar   Japanese Restaurant
# 19                       Aquarium                 Hotel
# 20                            Pub                Bakery
# 21             Mexican Restaurant           Flea Market
# 22                           Lake              Bus Line
# 23               Asian Restaurant           Coffee Shop
# 24                           Park                 Trail
# 25                    Coffee Shop           Yoga Studio
# 26                      Gift Shop             Bookstore
# 27                     Playground                 Trail
# 28                   Home Service        Ice Cream Shop
# 29                           Café      Sushi Restaurant
# 30                 Clothing Store        Cosmetics Shop
# 31                           Café                 Hotel
# 32             Italian Restaurant            Restaurant
# 33                    Coffee Shop    Italian Restaurant
# 34                           Café        Sandwich Place
# 35           Other Great Outdoors                 Trail
# 36                 Sandwich Place           Pizza Place
# 37                    Coffee Shop    Italian Restaurant
#
#      4th Most Common Venue        5th Most Common Venue  \
# 0               Steakhouse                        Hotel
# 1                     Café                   Steakhouse
# 2                      Gym                 Intersection
# 3           Farmers Market         Fast Food Restaurant
# 4                 Boutique                      Airport
# 5                   Bakery                         Café
# 6           Sandwich Place                 Burger Joint
# 7                      Bar           Mexican Restaurant
# 8               Baby Store                  Coffee Shop
# 9         Sushi Restaurant                   Restaurant
# 10              Restaurant          American Restaurant
# 11             Coffee Shop                          Gym
# 12          Sandwich Place                 Dance Studio
# 13              Sports Bar                   Restaurant
# 14              Restaurant           Italian Restaurant
# 15             Music Venue                         Café
# 16              Restaurant                   Steakhouse
# 17                Bus Line                  Yoga Studio
# 18               Bookstore               Sandwich Place
# 19                    Café               Scenic Lookout
# 20                    Park                         Café
# 21             Music Venue                    Bookstore
# 22             Swim School                  Yoga Studio
# 23                    Café                     Boutique
# 24            Tennis Court                  Yoga Studio
# 25          Ice Cream Shop               Cosmetics Shop
# 26            Dessert Shop  Eastern European Restaurant
# 27                Building                  Yoga Studio
# 28             Music Venue                  Yoga Studio
# 29      Italian Restaurant                        Diner
# 30                    Café    Middle Eastern Restaurant
# 31              Restaurant           Italian Restaurant
# 32                    Café                        Hotel
# 33                  Bakery          American Restaurant
# 34             Pizza Place               Cosmetics Shop
# 35                     Pub                      Dog Run
# 36        Sushi Restaurant                      Brewery
# 37  Furniture / Home Store                    Bookstore
#
#         6th Most Common Venue      7th Most Common Venue  \
# 0                  Restaurant               Burger Joint
# 1                      Bakery         Seafood Restaurant
# 2       Performing Arts Venue                  Pet Store
# 3                        Park                 Skate Park
# 4          Airport Food Court            Harbor / Marina
# 5                         Pub         Chinese Restaurant
# 6              Ice Cream Shop  Middle Eastern Restaurant
# 7         Dumpling Restaurant      Vietnamese Restaurant
# 8                       Diner                 Restaurant
# 9                Burger Joint                       Café
# 10                  Gastropub                        Gym
# 11           Sushi Restaurant         Italian Restaurant
# 12             Clothing Store             Breakfast Spot
# 13                Supermarket           Sushi Restaurant
# 14                  Gastropub                        Bar
# 15  Middle Eastern Restaurant                        Bar
# 16         Seafood Restaurant                  Gastropub
# 17           Doner Restaurant                   Festival
# 18                 Restaurant                     Bakery
# 19        Fried Chicken Joint                    Brewery
# 20                 Restaurant       Gym / Fitness Center
# 21                       Park  Cajun / Creole Restaurant
# 22           Doner Restaurant       Fast Food Restaurant
# 23                Men's Store               Cocktail Bar
# 24          Electronics Store           Doner Restaurant
# 25               Burger Joint                        Spa
# 26                        Bar                       Bank
# 27                    Dog Run       Fast Food Restaurant
# 28       Fast Food Restaurant             Farmers Market
# 29                  Bookstore             Sandwich Place
# 30                      Diner           Ramen Restaurant
# 31                     Bakery             Cosmetics Shop
# 32         Seafood Restaurant                   Beer Bar
# 33                Yoga Studio                       Park
# 34               Liquor Store               Burger Joint
# 35                   Festival       Fast Food Restaurant
# 36               Burger Joint              Burrito Place
# 37             Ice Cream Shop                    Brewery
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 0         Cosmetics Shop   American Restaurant              Thai Restaurant
# 1     Italian Restaurant              Beer Bar               Farmers Market
# 2              Nightclub          Climbing Gym                   Restaurant
# 3     Light Rail Station         Burrito Place                Auto Workshop
# 4          Boat or Ferry           Coffee Shop             Sculpture Garden
# 5     Italian Restaurant          Gourmet Shop                         Park
# 6   Gym / Fitness Center                   Spa                  Salad Place
# 7                 Bakery           Coffee Shop      Comfort Food Restaurant
# 8              Nightclub    Italian Restaurant            Convenience Store
# 9                    Pub       Bubble Tea Shop                          Gym
# 10         Deli / Bodega    Italian Restaurant                   Steakhouse
# 11                  Café            Restaurant             Greek Restaurant
# 12                   Gym                  Park             Doner Restaurant
# 13          Liquor Store   Fried Chicken Joint                   Bagel Shop
# 14                Bakery         Deli / Bodega          American Restaurant
# 15                  Bank            Smoke Shop        Portuguese Restaurant
# 16                   Gym          Burger Joint                Deli / Bodega
# 17  Fast Food Restaurant        Farmers Market           Falafel Restaurant
# 18         Poutine Place              Beer Bar                   Beer Store
# 19                 Plaza            Sports Bar                         Park
# 20    Mexican Restaurant        Breakfast Spot                      Theater
# 21             Speakeasy    Italian Restaurant                          Bar
# 22        Farmers Market    Falafel Restaurant                  Event Space
# 23           Pizza Place     French Restaurant                   Restaurant
# 24            Donut Shop   Dumpling Restaurant  Eastern European Restaurant
# 25    Mexican Restaurant                  Café           Salon / Barbershop
# 26         Movie Theater               Dog Run                   Restaurant
# 27        Farmers Market    Falafel Restaurant                  Event Space
# 28    Falafel Restaurant           Event Space         Ethiopian Restaurant
# 29         Burrito Place            Restaurant                          Pub
# 30  Fast Food Restaurant   Sporting Goods Shop          Japanese Restaurant
# 31          Cocktail Bar        Clothing Store               Breakfast Spot
# 32          Cocktail Bar        Breakfast Spot               Farmers Market
# 33    Seafood Restaurant        Sandwich Place                  Cheese Shop
# 34     Martial Arts Dojo     Jewish Restaurant            Indian Restaurant
# 35        Farmers Market    Falafel Restaurant                  Event Space
# 36                   Pub           Coffee Shop                    Pet Store
# 37       Bubble Tea Shop                  Café                   Restaurant

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 0, 1, 1, 1, 1, 1, 1], dtype=int32)

# %%
toronto_merged = toronto_data

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postcode          Borough                   Neighbourhood   Latitude  \
# 0      M4E     East Toronto                     The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3      M4M     East Toronto                 Studio District  43.659526
# 4      M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.293031               1     Health Food Store  Other Great Outdoors
# 1 -79.352188               1      Greek Restaurant           Coffee Shop
# 2 -79.315572               1                  Park        Sandwich Place
# 3 -79.340923               0                  Café           Coffee Shop
# 4 -79.388790               1                  Park                  Lake
#
#   3rd Most Common Venue   4th Most Common Venue 5th Most Common Venue  \
# 0                 Trail                     Pub               Dog Run
# 1    Italian Restaurant  Furniture / Home Store             Bookstore
# 2           Pizza Place        Sushi Restaurant               Brewery
# 3    Italian Restaurant                  Bakery   American Restaurant
# 4              Bus Line             Swim School           Yoga Studio
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0              Festival  Fast Food Restaurant        Farmers Market
# 1        Ice Cream Shop               Brewery       Bubble Tea Shop
# 2          Burger Joint         Burrito Place                   Pub
# 3           Yoga Studio                  Park    Seafood Restaurant
# 4      Doner Restaurant  Fast Food Restaurant        Farmers Market
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Falafel Restaurant            Event Space
# 1                  Café             Restaurant
# 2           Coffee Shop              Pet Store
# 3        Sandwich Place            Cheese Shop
# 4    Falafel Restaurant            Event Space

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_merged
# Out:
#    Postcode           Borough  \
# 0       M4E      East Toronto
# 1       M4K      East Toronto
# 2       M4L      East Toronto
# 3       M4M      East Toronto
# 4       M4N   Central Toronto
# 5       M4P   Central Toronto
# 6       M4R   Central Toronto
# 7       M4S   Central Toronto
# 8       M4T   Central Toronto
# 9       M4V   Central Toronto
# 10      M4W  Downtown Toronto
# 11      M4X  Downtown Toronto
# 12      M4Y  Downtown Toronto
# 13      M5A  Downtown Toronto
# 14      M5B  Downtown Toronto
# 15      M5C  Downtown Toronto
# 16      M5E  Downtown Toronto
# 17      M5G  Downtown Toronto
# 18      M5H  Downtown Toronto
# 19      M5J  Downtown Toronto
# 20      M5K  Downtown Toronto
# 21      M5L  Downtown Toronto
# 22      M5N   Central Toronto
# 23      M5P   Central Toronto
# 24      M5R   Central Toronto
# 25      M5S  Downtown Toronto
# 26      M5T  Downtown Toronto
# 27      M5V  Downtown Toronto
# 28      M5W  Downtown Toronto
# 29      M5X  Downtown Toronto
# 30      M6G  Downtown Toronto
# 31      M6H      West Toronto
# 32      M6J      West Toronto
# 33      M6K      West Toronto
# 34      M6P      West Toronto
# 35      M6R      West Toronto
# 36      M6S      West Toronto
# 37      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude  \
# 0                                         The Beaches  43.676357 -79.293031
# 1                        The Danforth West, Riverdale  43.679557 -79.352188
# 2                      The Beaches West, India Bazaar  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 4                                       Lawrence Park  43.728020 -79.388790
# 5                                    Davisville North  43.712751 -79.390197
# 6                                  North Toronto West  43.715383 -79.405678
# 7                                          Davisville  43.704324 -79.388790
# 8                         Moore Park, Summerhill East  43.689574 -79.383160
# 9   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 10                                           Rosedale  43.679563 -79.377529
# 11                        Cabbagetown, St. James Town  43.667967 -79.367675
# 12                               Church and Wellesley  43.665860 -79.383160
# 13                          Harbourfront, Regent Park  43.654260 -79.360636
# 14                           Ryerson, Garden District  43.657162 -79.378937
# 15                                     St. James Town  43.651494 -79.375418
# 16                                        Berczy Park  43.644771 -79.373306
# 17                                 Central Bay Street  43.657952 -79.387383
# 18                           Adelaide, King, Richmond  43.650571 -79.384568
# 19  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 20           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 21                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 22                                           Roselawn  43.711695 -79.416936
# 23                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 24                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 25                     Harbord, University of Toronto  43.662696 -79.400049
# 26          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 27  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 28                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 29             First Canadian Place, Underground city  43.648429 -79.382280
# 30                                           Christie  43.669542 -79.422564
# 31                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 32                           Little Portugal, Trinity  43.647927 -79.419750
# 33       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 34                      High Park, The Junction South  43.661608 -79.464763
# 35                             Parkdale, Roncesvalles  43.648960 -79.456325
# 36                                 Runnymede, Swansea  43.651571 -79.484450
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
#
#     Cluster Labels 1st Most Common Venue          2nd Most Common Venue  \
# 0                1     Health Food Store           Other Great Outdoors
# 1                1      Greek Restaurant                    Coffee Shop
# 2                1                  Park                 Sandwich Place
# 3                0                  Café                    Coffee Shop
# 4                1                  Park                           Lake
# 5                1           Pizza Place                          Hotel
# 6                1   Sporting Goods Shop                    Coffee Shop
# 7                1        Sandwich Place                    Pizza Place
# 8                1            Playground                           Park
# 9                1           Coffee Shop                            Pub
# 10               1                  Park                     Playground
# 11               1           Coffee Shop                     Restaurant
# 12               0           Coffee Shop            Japanese Restaurant
# 13               1           Coffee Shop                            Pub
# 14               1           Coffee Shop                 Clothing Store
# 15               0           Coffee Shop                           Café
# 16               1           Coffee Shop                   Cocktail Bar
# 17               3           Coffee Shop                           Café
# 18               1           Coffee Shop                           Café
# 19               1           Coffee Shop                       Aquarium
# 20               1           Coffee Shop                           Café
# 21               1           Coffee Shop                           Café
# 22               0                Garden                   Home Service
# 23               1                 Trail                  Jewelry Store
# 24               2           Coffee Shop                           Café
# 25               1                  Café                            Bar
# 26               1                  Café  Vegetarian / Vegan Restaurant
# 27               2       Airport Service                 Airport Lounge
# 28               4           Coffee Shop             Italian Restaurant
# 29               1           Coffee Shop                           Café
# 30               1                  Café                  Grocery Store
# 31               1              Pharmacy                    Supermarket
# 32               1                   Bar               Asian Restaurant
# 33               1           Coffee Shop                           Café
# 34               1                  Café             Mexican Restaurant
# 35               1        Breakfast Spot                      Gift Shop
# 36               0           Coffee Shop                           Café
# 37               1            Comic Shop                  Garden Center
#
#    3rd Most Common Venue   4th Most Common Venue        5th Most Common Venue  \
# 0                  Trail                     Pub                      Dog Run
# 1     Italian Restaurant  Furniture / Home Store                    Bookstore
# 2            Pizza Place        Sushi Restaurant                      Brewery
# 3     Italian Restaurant                  Bakery          American Restaurant
# 4               Bus Line             Swim School                  Yoga Studio
# 5      Food & Drink Shop          Sandwich Place                 Dance Studio
# 6            Yoga Studio          Ice Cream Shop               Cosmetics Shop
# 7           Dessert Shop             Coffee Shop                          Gym
# 8                  Trail            Tennis Court                  Yoga Studio
# 9     Light Rail Station              Sports Bar                   Restaurant
# 10                 Trail                Building                  Yoga Studio
# 11           Pizza Place                  Bakery                         Café
# 12               Gay Bar        Sushi Restaurant                   Restaurant
# 13                Bakery                    Park                         Café
# 14        Cosmetics Shop                    Café    Middle Eastern Restaurant
# 15                 Hotel              Restaurant           Italian Restaurant
# 16           Cheese Shop                    Café                   Steakhouse
# 17    Italian Restaurant          Sandwich Place                 Burger Joint
# 18                   Bar              Steakhouse                        Hotel
# 19                 Hotel                    Café               Scenic Lookout
# 20                 Hotel              Restaurant           Italian Restaurant
# 21                 Hotel              Restaurant          American Restaurant
# 22        Ice Cream Shop             Music Venue                  Yoga Studio
# 23      Sushi Restaurant                Bus Line                  Yoga Studio
# 24        Sandwich Place             Pizza Place               Cosmetics Shop
# 25   Japanese Restaurant               Bookstore               Sandwich Place
# 26    Chinese Restaurant                     Bar           Mexican Restaurant
# 27      Airport Terminal                Boutique                      Airport
# 28            Restaurant                    Café                        Hotel
# 29                 Hotel              Restaurant                   Steakhouse
# 30                  Park              Baby Store                  Coffee Shop
# 31                Bakery             Music Venue                         Café
# 32           Coffee Shop                    Café                     Boutique
# 33        Breakfast Spot                     Gym                 Intersection
# 34           Flea Market             Music Venue                    Bookstore
# 35             Bookstore            Dessert Shop  Eastern European Restaurant
# 36      Sushi Restaurant      Italian Restaurant                        Diner
# 37               Brewery          Farmers Market         Fast Food Restaurant
#
#         6th Most Common Venue      7th Most Common Venue  \
# 0                    Festival       Fast Food Restaurant
# 1              Ice Cream Shop                    Brewery
# 2                Burger Joint              Burrito Place
# 3                 Yoga Studio                       Park
# 4            Doner Restaurant       Fast Food Restaurant
# 5              Clothing Store             Breakfast Spot
# 6                Burger Joint                        Spa
# 7            Sushi Restaurant         Italian Restaurant
# 8           Electronics Store           Doner Restaurant
# 9                 Supermarket           Sushi Restaurant
# 10                    Dog Run       Fast Food Restaurant
# 11                        Pub         Chinese Restaurant
# 12               Burger Joint                       Café
# 13                 Restaurant       Gym / Fitness Center
# 14                      Diner           Ramen Restaurant
# 15                     Bakery             Cosmetics Shop
# 16                     Bakery         Seafood Restaurant
# 17             Ice Cream Shop  Middle Eastern Restaurant
# 18                 Restaurant               Burger Joint
# 19        Fried Chicken Joint                    Brewery
# 20                  Gastropub                        Bar
# 21                  Gastropub                        Gym
# 22       Fast Food Restaurant             Farmers Market
# 23           Doner Restaurant                   Festival
# 24               Liquor Store               Burger Joint
# 25                 Restaurant                     Bakery
# 26        Dumpling Restaurant      Vietnamese Restaurant
# 27         Airport Food Court            Harbor / Marina
# 28         Seafood Restaurant                   Beer Bar
# 29         Seafood Restaurant                  Gastropub
# 30                      Diner                 Restaurant
# 31  Middle Eastern Restaurant                        Bar
# 32                Men's Store               Cocktail Bar
# 33      Performing Arts Venue                  Pet Store
# 34                       Park  Cajun / Creole Restaurant
# 35                        Bar                       Bank
# 36                  Bookstore             Sandwich Place
# 37                       Park                 Skate Park
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 0         Farmers Market    Falafel Restaurant                  Event Space
# 1        Bubble Tea Shop                  Café                   Restaurant
# 2                    Pub           Coffee Shop                    Pet Store
# 3     Seafood Restaurant        Sandwich Place                  Cheese Shop
# 4         Farmers Market    Falafel Restaurant                  Event Space
# 5                    Gym                  Park             Doner Restaurant
# 6     Mexican Restaurant                  Café           Salon / Barbershop
# 7                   Café            Restaurant             Greek Restaurant
# 8             Donut Shop   Dumpling Restaurant  Eastern European Restaurant
# 9           Liquor Store   Fried Chicken Joint                   Bagel Shop
# 10        Farmers Market    Falafel Restaurant                  Event Space
# 11    Italian Restaurant          Gourmet Shop                         Park
# 12                   Pub       Bubble Tea Shop                          Gym
# 13    Mexican Restaurant        Breakfast Spot                      Theater
# 14  Fast Food Restaurant   Sporting Goods Shop          Japanese Restaurant
# 15          Cocktail Bar        Clothing Store               Breakfast Spot
# 16    Italian Restaurant              Beer Bar               Farmers Market
# 17  Gym / Fitness Center                   Spa                  Salad Place
# 18        Cosmetics Shop   American Restaurant              Thai Restaurant
# 19                 Plaza            Sports Bar                         Park
# 20                Bakery         Deli / Bodega          American Restaurant
# 21         Deli / Bodega    Italian Restaurant                   Steakhouse
# 22    Falafel Restaurant           Event Space         Ethiopian Restaurant
# 23  Fast Food Restaurant        Farmers Market           Falafel Restaurant
# 24     Martial Arts Dojo     Jewish Restaurant            Indian Restaurant
# 25         Poutine Place              Beer Bar                   Beer Store
# 26                Bakery           Coffee Shop      Comfort Food Restaurant
# 27         Boat or Ferry           Coffee Shop             Sculpture Garden
# 28          Cocktail Bar        Breakfast Spot               Farmers Market
# 29                   Gym          Burger Joint                Deli / Bodega
# 30             Nightclub    Italian Restaurant            Convenience Store
# 31                  Bank            Smoke Shop        Portuguese Restaurant
# 32           Pizza Place     French Restaurant                   Restaurant
# 33             Nightclub          Climbing Gym                   Restaurant
# 34             Speakeasy    Italian Restaurant                          Bar
# 35         Movie Theater               Dog Run                   Restaurant
# 36         Burrito Place            Restaurant                          Pub
# 37    Light Rail Station         Burrito Place                Auto Workshop

# %%
# Determine all venues that are not food-related
non_resto= ['Gym', 'Park', 'Hotel', 'Light Rail Station', 'Studio', 'Spa', 'Garden', 'Garden Center', 'Gift Shop', 'Bookstore', 'Airport', 'Boutique', 'Sporting Goods Shop', 'Summer Camp', 'Jewelry Store', 'Airport Service', 'Comic Shop', 'Pharmacy', 'Supermarket', 'Trail', 'Cosmetics Shop', 'Men\'s Store', 'Stadium', 'Yoga Studio', 'Performing Arts Venue', 'Arts & Crafts Store']

# Build the dataframe 
hs1 = toronto_merged[-toronto_merged['1st Most Common Venue'].isin(non_resto)]
hs2 = hs1[-hs1['2nd Most Common Venue'].isin(non_resto)]
hs3 = hs2[-hs2['3rd Most Common Venue'].isin(non_resto)]
hs4 = hs3[-hs3['4th Most Common Venue'].isin(non_resto)]
hs5 = hs4[-hs4['5th Most Common Venue'].isin(non_resto)]
hs6 = hs5[-hs5['6th Most Common Venue'].isin(non_resto)]
hs7 = hs6[-hs6['7th Most Common Venue'].isin(non_resto)]
hs8 = hs7[-hs7['8th Most Common Venue'].isin(non_resto)]
hs9 = hs8[-hs8['9th Most Common Venue'].isin(non_resto)]
hotspots = hs9[-hs9['10th Most Common Venue'].isin(non_resto)]

#Show resulting hotspots
hotspots
# Out:
#    Postcode           Borough                              Neighbourhood  \
# 16      M5E  Downtown Toronto                                Berczy Park
# 26      M5T  Downtown Toronto  Chinatown, Grange Park, Kensington Market
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 16  43.644771 -79.373306               1           Coffee Shop
# 26  43.653206 -79.400049               1                  Café
#
#             2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 16                   Cocktail Bar           Cheese Shop                  Café
# 26  Vegetarian / Vegan Restaurant    Chinese Restaurant                   Bar
#
#    5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 16            Steakhouse                Bakery     Seafood Restaurant
# 26    Mexican Restaurant   Dumpling Restaurant  Vietnamese Restaurant
#
#    8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 16    Italian Restaurant              Beer Bar           Farmers Market
# 26                Bakery           Coffee Shop  Comfort Food Restaurant

# %%
(43.704324, -79.388790)
(43.667967, -79.367675)
(43.644771, -79.373306)
(43.653206, -79.400049)
(43.647927, -79.419750)
(43.651571, -79.484450)
# Out:
# (43.651571, -79.48445)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
hotspots.loc[16, 'Neighbourhood']
# Out:
# 'Berczy Park'

# %%
neighbourhood_latitude = hotspots.loc[16, 'Latitude'] # neighbourhood latitude value
neighbourhood_longitude = hotspots.loc[16, 'Longitude'] # neighbourhood longitude value

neighbourhood_name = hotspots.loc[16, 'Neighbourhood'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of Berczy Park are 43.644770799999996, -79.3733064.

# %%
# create map of Manhattan using latitude and longitude values
map_hotspots = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(hotspots['Latitude'], hotspots['Longitude'], hotspots['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_hotspots)  
    
map_hotspots
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
client_id = "XWCAJYVE5H1ZRLXFO1H5HQRKSYVLOTRW2M1ITBMJXIV0BO5K"
client_secret = "K0M510H4PGPZMGGBJN0COJAOA4TI3G5HRSLKKRUKSQRCEFTB"
version = "20180605"
category = "5bae9231bedf3950379f89da"

optimalLocations = [
    (43.704324, -79.388790),
    (43.667967, -79.367675),
    (43.644771, -79.373306),
    (43.653206, -79.400049), 
    (43.647927, -79.419750),
    (43.651571, -79.484450)
]


def getRestaurants(lat, lon, radius=500, limit=100):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}".format(client_id, client_secret, version, lat, lon, category, radius, limit)
    response = requests.get(url).json()

    print(response)

def getAllLocations():
    for coords in optimalLocations:
        getRestaurants(coords[0],coords[1])

getAllLocations()
# Out:
# {'meta': {'code': 200, 'requestId': '5d719429bf7dde17f1e02595'}, 'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."}, 'headerLocation': 'Davisville', 'headerFullLocation': 'Davisville, Toronto', 'headerLocationGranularity': 'neighborhood', 'query': 'syrian restaurant', 'totalResults': 0, 'suggestedBounds': {'ne': {'lat': 43.7088240045, 'lng': -79.38257681802163}, 'sw': {'lat': 43.6998239955, 'lng': -79.39500318197837}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': []}]}}
# {'meta': {'code': 200, 'requestId': '5d719429c267e90038f336b3'}, 'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."}, 'headerLocation': 'Cabbagetown', 'headerFullLocation': 'Cabbagetown, Toronto', 'headerLocationGranularity': 'neighborhood', 'query': 'syrian restaurant', 'totalResults': 0, 'suggestedBounds': {'ne': {'lat': 43.6724670045, 'lng': -79.3614655826597}, 'sw': {'lat': 43.663466995499995, 'lng': -79.3738844173403}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': []}]}}
# {'meta': {'code': 200, 'requestId': '5d71942adb1d81002c89fd5d'}, 'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."}, 'headerLocation': 'Downtown Toronto', 'headerFullLocation': 'Downtown Toronto, Toronto', 'headerLocationGranularity': 'neighborhood', 'query': 'syrian restaurant', 'totalResults': 0, 'suggestedBounds': {'ne': {'lat': 43.6492710045, 'lng': -79.36709898083477}, 'sw': {'lat': 43.640270995499996, 'lng': -79.37951301916523}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': []}]}}
# {'meta': {'code': 200, 'requestId': '5d71942ad03d290039dd8be1'}, 'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."}, 'headerLocation': 'Kensington', 'headerFullLocation': 'Kensington, Toronto', 'headerLocationGranularity': 'neighborhood', 'query': 'syrian restaurant', 'totalResults': 0, 'suggestedBounds': {'ne': {'lat': 43.6577060045, 'lng': -79.39384110909378}, 'sw': {'lat': 43.648705995499995, 'lng': -79.4062568909062}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': []}]}}
# {'meta': {'code': 200, 'requestId': '5d71942a23bb8e0038d24db0'}, 'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."}, 'headerLocation': 'Trinity Bellwoods', 'headerFullLocation': 'Trinity Bellwoods, Toronto', 'headerLocationGranularity': 'neighborhood', 'query': 'syrian restaurant', 'totalResults': 0, 'suggestedBounds': {'ne': {'lat': 43.652427004500005, 'lng': -79.41354265471267}, 'sw': {'lat': 43.6434269955, 'lng': -79.42595734528732}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': []}]}}
# {'meta': {'code': 200, 'requestId': '5d71942bdb1d81002c8a015f'}, 'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."}, 'headerLocation': 'Bloor West Village', 'headerFullLocation': 'Bloor West Village, Toronto', 'headerLocationGranularity': 'neighborhood', 'query': 'syrian restaurant', 'totalResults': 0, 'suggestedBounds': {'ne': {'lat': 43.6560710045, 'lng': -79.47824227809753}, 'sw': {'lat': 43.647070995499995, 'lng': -79.49065772190247}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': []}]}}

# %%
#!conda install -c conda-forge geopy 
        
import geopy.distance
import sys

cn = (43.6426, -79.3871)

def getClosestToCNTower():
    minDistance = sys.maxsize
    minCoords = cn
    for coords in optimalLocations:
        distance = (geopy.distance.distance(coords,cn))
        if distance < minDistance:
            minDistance = distance
            minCoords = coords
    return minCoords
print (sys.maxsize)
print(getClosestToCNTower())
# Out:
# 9223372036854775807
# (43.644771, -79.373306)

# %% [markdown]
# # # RESULTS AND DISSCUSSION

# %%
ALL THE PLOTTED DATA ARE SOURCED FROM THE NEIGHBOURHOOD BOROUGH AND POST CODDES FROM TORONTO  THOSE ARE BASED ON LATITUDE AND LONGITUDE.
PANDAS DATAFRAME WERE CREATED FORM LATITUDE AND LONGITUDE MERGED DATA FOR THAT TORANTO COORDINATES WERE SUPER IMPOSED. 
FOLIUM WAS USED TO GENERATE THE MAP.
NEIGHBOURHOOD ARE CLUSTERED AND SEGMENTED AND SHOWN ON THE MAP CREATED.
WITH THIS DATA AND FOURSQUARE API SCORE, VENUES EXPLORED IN DESIGNATED NEIGHBOURHOOD.
RESTAURANTS AND FOOD AREA ARE HIGHLIGHTED IN THE PANDAS AND DATAFRAME AND SORTED TO ISOLATE THE RESTAURANT HOTSPOT IN THE TOWN.
IF NEIGHBOURHOOD HAD TOTAL 10 RESTAURANT IN THE AREA, WOULD BE CONSIDERED AS HOTSPOT.
THIS BRINGS DOWN DATA TO 6 HOTSPOTS, WHICH BRINGS NEXT CHALLANGE TO SYSTEM. THE PRESENCE OF COMPETATIVE RESTAURANT IN THE CITY.
THE API OF FOURSQUARE RESULTED IN A LACK OF COMPITATIVE RESTAURANT IN ISOLATED RESTAURANT HOTSPOTS.
THIS CAN BE CONSIDRED AS EXCELLENT NEWS TO DEAL AND START WITH. ANY ONE OF ARE CAN BE CHOOSEN WHERE COMPETITICE RESTAURENT PRESENT. 
THE HOTSPOT WHICH WAS CLOSE TO CN TOWER AND IT IS A 553.3 METER. MAPPING SHOW THAT BERCZY PARK IS WITHIN THE  CLOSET PROXIMITY TO THE CN TOWER. 
RESTAURANT WOULD BE MOST SUITABLE FOR OPTIMAL LOCATION OF PLANNED RESTAURANT.

# %% [markdown]
# ## TAKE

# %%
THERE IS A LACK OF RESTAURANT PLANNED. OTHER RESTAURANT FROM INDIA AND CHINA ARE PRESENT IN THE REGION. 
THE BRACZY IS BEST LOCATION TO OPEN THE RESTARURANT
